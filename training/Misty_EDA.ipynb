# %% [markdown]
# ## Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Data

# %%
data = pd.read_csv('challenge.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
# x1             10000 non-null object
# x2             10000 non-null object
# x3             10000 non-null object
# x4             10000 non-null object
# x5             10000 non-null object
# x6             10000 non-null int64
# y              10000 non-null float64
# x7             10000 non-null int64
# x8             10000 non-null object
# x9             10000 non-null int64
# x10            10000 non-null int64
# x11            10000 non-null float64
# x12            10000 non-null float64
# x13            10000 non-null float64
# x14            10000 non-null int64
# x15            10000 non-null object
# x16            10000 non-null object
# x17            10000 non-null object
# x18            10000 non-null int64
# x19            10000 non-null int64
# x20            10000 non-null int64
# x21            10000 non-null int64
# x22            10000 non-null int64
# x23            10000 non-null object
# x24            8231 non-null object
# x25            8231 non-null object
# x26            7658 non-null object
# Unnamed: 27    343 non-null object
# Unnamed: 28    1 non-null float64
# dtypes: float64(5), int64(10), object(14)
# memory usage: 2.2+ MB

# %%
data.select_dtypes('object').columns # 12 of the features are non numeric
# Out:
# Index(['x2', 'x3', 'x4', 'x5', 'x8', 'x15', 'x16', 'x17', 'x23', 'x24', 'x25',
#        'x26'],
#       dtype='object')

# %%
data.describe()
# Out:
#                  x6             y            x7            x9           x10  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    1989.585900      0.427953     28.212400      2.400900      0.722100
# std       22.920972     20.726503     11.398424      2.319335      0.844596
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1984.000000      0.000000     20.000000      1.000000      0.000000
# 50%     1993.000000      0.000000     25.000000      2.000000      1.000000
# 75%     1998.000000      0.000000     34.000000      3.000000      1.000000
# max     2006.000000   2000.000000    100.000000     26.000000      4.000000
#
#                 x11           x12           x13           x14           x18  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.027339      0.165077      0.055035     74.486500      0.037900
# std        0.034747      0.111654      0.369048     49.218869      0.190964
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.080720      0.000000     42.000000      0.000000
# 50%        0.018692      0.144578      0.000000     61.000000      0.000000
# 75%        0.041096      0.226441      0.000000     93.000000      0.000000
# max        1.000000      1.000000      7.000000    976.000000      1.000000
#
#                 x19           x20           x21           x22  Unnamed: 28
# count  10000.000000  10000.000000  10000.000000  10000.000000          1.0
# mean       0.020500      0.350800      0.540200      0.041300          3.0
# std        0.155827      0.477244      0.498406      0.198993          NaN
# min        0.000000      0.000000      0.000000      0.000000          3.0
# 25%        0.000000      0.000000      0.000000      0.000000          3.0
# 50%        0.000000      0.000000      1.000000      0.000000          3.0
# 75%        0.000000      1.000000      1.000000      0.000000          3.0
# max        7.000000      1.000000      1.000000      1.000000          3.0

# %%
# {‘pearson’, ‘kendall’, ‘spearman’}
data.corr(method='pearson').style.format('{:.2}').background_gradient(cmap='coolwarm')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/colors.py:512: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col4 {
#             background-color:  #4961d2;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col5 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col6 {
#             background-color:  #5a78e4;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col7 {
#             background-color:  #4e68d8;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col8 {
#             background-color:  #4257c9;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col9 {
#             background-color:  #455cce;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col10 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col11 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col12 {
#             background-color:  #506bda;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col13 {
#             background-color:  #5470de;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row0_col14 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col2 {
#             background-color:  #a1c0ff;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col3 {
#             background-color:  #4257c9;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col4 {
#             background-color:  #506bda;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col5 {
#             background-color:  #d2dbe8;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col6 {
#             background-color:  #5470de;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col7 {
#             background-color:  #4c66d6;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col8 {
#             background-color:  #3f53c6;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col9 {
#             background-color:  #5a78e4;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col10 {
#             background-color:  #efcebd;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col11 {
#             background-color:  #6485ec;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col12 {
#             background-color:  #445acc;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col13 {
#             background-color:  #6384eb;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row1_col14 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col0 {
#             background-color:  #7a9df8;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col1 {
#             background-color:  #cdd9ec;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col2 {
#             background-color:  #b40426;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col3 {
#             background-color:  #5e7de7;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col4 {
#             background-color:  #4c66d6;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col5 {
#             background-color:  #c3d5f4;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col6 {
#             background-color:  #5b7ae5;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col7 {
#             background-color:  #3e51c5;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col8 {
#             background-color:  #4e68d8;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col9 {
#             background-color:  #3e51c5;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col10 {
#             background-color:  #82a6fb;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col11 {
#             background-color:  #c9d7f0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col12 {
#             background-color:  #3d50c3;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col13 {
#             background-color:  #4358cb;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row2_col14 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col0 {
#             background-color:  #ccd9ed;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col1 {
#             background-color:  #cfdaea;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col2 {
#             background-color:  #bad0f8;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col3 {
#             background-color:  #b40426;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col4 {
#             background-color:  #a9c6fd;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col5 {
#             background-color:  #a6c4fe;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col6 {
#             background-color:  #e1dad6;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col7 {
#             background-color:  #5470de;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col8 {
#             background-color:  #d7dce3;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col9 {
#             background-color:  #536edd;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col10 {
#             background-color:  #9bbcff;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col11 {
#             background-color:  #7ea1fa;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col12 {
#             background-color:  #85a8fc;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col13 {
#             background-color:  #536edd;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row3_col14 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col0 {
#             background-color:  #cedaeb;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col1 {
#             background-color:  #d3dbe7;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col2 {
#             background-color:  #a6c4fe;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col3 {
#             background-color:  #a2c1ff;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col4 {
#             background-color:  #b40426;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col5 {
#             background-color:  #b7cff9;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col6 {
#             background-color:  #455cce;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col7 {
#             background-color:  #3c4ec2;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col8 {
#             background-color:  #b7cff9;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col9 {
#             background-color:  #445acc;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col10 {
#             background-color:  #94b6ff;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col11 {
#             background-color:  #7b9ff9;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col12 {
#             background-color:  #8badfd;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col13 {
#             background-color:  #4358cb;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row4_col14 {
#             background-color:  #3b4cc0;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002row5_col0 {
#             background-color:  #93b5fe;
#         }    #T_612fe432_563f_11e9_a397_0242ac1c0002ro

# %% [markdown]
# ## Target

# %%
y = np.where(data['y'] > 0, 1, 0)

# %%
(y == 0).sum(), (y == 1).sum() # so imbalanced
# Out:
# (9850, 150)

# %% [markdown]
# ## Predictors

# %% [markdown]
# ### x1
# UID

# %%
data['x1'].describe() # x1 is just uid, can be dropped
# Out:
# count       10000
# unique      10000
# top       id89789
# freq            1
# Name: x1, dtype: object

# %% [markdown]
# ### x2
# OS version

# %%
data['x2'].describe()
# Out:
# count     10000
# unique       18
# top       8.0.0
# freq       3454
# Name: x2, dtype: object

# %%
data['x2'].value_counts() # can all possibly be condensed to the major version
# Out:
# 8.0.0    3454
# 7        1729
# 8.1.0    1474
# 7.1.1     931
# 6.0.1     905
# 9         474
# 7.1.2     309
# 5.1.1     295
# 6         207
# 4.4.2      61
# 5.1        55
# 5          37
# 5.0.1      28
# 5.0.2      26
# 4.4.4      12
# 4.4.3       1
# 4.4         1
# 7.1         1
# Name: x2, dtype: int64

# %% [markdown]
# ### x4
# language

# %%
data['x4'].value_counts() # can be lowercased then [:2]
# Out:
# US                  5765
# GB                   870
# CA                   687
# FR                   411
# SG                   407
# SE                   331
# FI                   328
# AU                   297
# NZ                   278
# DK                   212
# DE                   186
# NO                   134
# CA_US                 18
# MX                     8
# MY                     7
# VN                     6
# NL                     5
# DK_US                  2
# MX_US                  2
# ES                     2
# GB_US                  2
# CH                     2
# NZ_US                  2
# TR                     2
# TH                     2
# AT                     2
# IN                     1
# EU_GB                  1
# CA_GB_US               1
# PL                     1
# JP                     1
# PT                     1
# GB_NL_US               1
# GR                     1
# PE                     1
# AT_DE                  1
# DZ                     1
# AU_SG                  1
# LTD._NS-P11A8100       1
# NO_SE                  1
# SA                     1
# AU_GB                  1
# DK_LT                  1
# US_other               1
# FR_RO                  1
# DE_GB_US               1
# TR_US_VE               1
# CA_NZ_US               1
# AU_GB_US               1
# SG_US                  1
# DK_SE                  1
# GB_SG                  1
# KR                     1
# HK_SG                  1
# GH                     1
# BA                     1
# GB_IL                  1
# IE                     1
# Name: x4, dtype: int64

# %% [markdown]
# ### x5

# %%
data['x5'].value_counts() #
# Out:
# 0     6285
# 1     3508
# 2      206
# US       1
# Name: x5, dtype: int64

# %% [markdown]
# ### x6, x7
# Year or birth and age as of 2018

# %%
data[['x6', 'x7']].head() # can drop x6
# Out:
#      x6  x7
# 0  1997  21
# 1  1999  19
# 2  1996  22
# 3  1976  42
# 4  1989  29

# %% [markdown]
# ### x8

# %%
data['x8'].value_counts()
# Out:
# 0        9801
# 1         182
# 2          14
# 3           2
# FALSE       1
# Name: x8, dtype: int64

# %% [markdown]
# ### x9, x10, x11, x12, x13, x14

# %%
tmp = ['x9', 'x10', 'x11', 'x12', 'x13', 'x14'] 
data[tmp].head()
# Out:
#    x9  x10       x11       x12  x13  x14
# 0   1    0  0.000000  0.036145  0.0   83
# 1   2    0  0.000000  0.529412  0.0  102
# 2   1    0  0.031915  0.063830  0.0   94
# 3   2    1  0.000000  0.200000  0.0   50
# 4   2    2  0.028571  0.071429  0.0   70

# %%
data[tmp].describe() # x14 can be reduced by /1000
# Out:
#                  x9           x10           x11           x12           x13  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       2.400900      0.722100      0.027339      0.165077      0.055035
# std        2.319335      0.844596      0.034747      0.111654      0.369048
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      0.000000      0.080720      0.000000
# 50%        2.000000      1.000000      0.018692      0.144578      0.000000
# 75%        3.000000      1.000000      0.041096      0.226441      0.000000
# max       26.000000      4.000000      1.000000      1.000000      7.000000
#
#                 x14
# count  10000.000000
# mean      74.486500
# std       49.218869
# min        0.000000
# 25%       42.000000
# 50%       61.000000
# 75%       93.000000
# max      976.000000

# %% [markdown]
# ### x15
# phone

# %%
data['x15'].value_counts() # can be lowercased
# Out:
# samsung                   4867
# LGE                       1648
# HUAWEI                     824
# motorola                   604
# ZTE                        378
# OnePlus                    193
# OPPO                       160
# Sony                       160
# Google                     136
# TCL                        126
# Xiaomi                      98
# asus                        72
# AlcatelOneTouch             65
# HMD Global                  51
# ALCATEL                     50
# Alcatel                     48
# HTC                         45
# Alco                        44
# LENOVO                      36
# google                      29
# Coolpad                     27
# Yulong                      23
# Vodafone                    22
# BLU                         22
# ANS                         15
# WIKO                        15
# Razer                       14
# Acer                        13
# Quanta                      10
# Blackview                   10
#                           ...
# blackberry                   1
# SKY DEVICES                  1
# Ulefone                      1
# Motorola                     1
# MAZE                         1
# Unnecto                      1
# Digi-Land                    1
# Plus One Japan Limited       1
# Foxconn                      1
# UMI                          1
# HAFURY                       1
# IUNI                         1
# htc                          1
# Maze                         1
# Shaghal Ltd dBA Ematic       1
# HOMTOM                       1
# Elite 4                      1
# Hewlett-Packard              1
# meizu                        1
# LG Electronics               1
# NOTE                         1
# AMGOO                        1
# TCL ALCATEL ONETOUCH         1
# Energizer                    1
# NUVISION                     1
# rockchip                     1
# innotek GmbH                 1
# TECNO MOBILE LIMITED         1
# Vanzo                        1
# myPhone                      1
# Name: x15, Length: 127, dtype: int64

# %% [markdown]
# ### x16
# Some comapnies name

# %%
data['x16'].value_counts() # should have been a binary
# Out:
# 0                            9706
# 1                             293
# SHENZHEN GIEC DIGITAL CO.       1
# Name: x16, dtype: int64

# %% [markdown]
# ### x17
# Some companies

# %%
data['x17'].value_counts()
# Out:
# 8       4928
# 7       2969
# 6       1112
# 9        474
# 5        441
# 4         75
# LTD.       1
# Name: x17, dtype: int64

# %% [markdown]
# ### x18, 19, 20, 21, 22

# %%
tmp = ['x18', 'x19', 'x20', 'x21', 'x22']
data[tmp].describe()
# Out:
#                 x18           x19           x20           x21           x22
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.037900      0.020500      0.350800      0.540200      0.041300
# std        0.190964      0.155827      0.477244      0.498406      0.198993
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      1.000000      0.000000
# 75%        0.000000      0.000000      1.000000      1.000000      0.000000
# max        1.000000      7.000000      1.000000      1.000000      1.000000

# %% [markdown]
# ### x23

# %%
data['x23'].value_counts() # almost binary
# Out:
# TRUE     5952
# FALSE    4047
# 0           1
# Name: x23, dtype: int64

# %% [markdown]
# ### x24
# Referral

# %%
data['x24'].value_counts()
# Out:
# komistplay-i27ca6ba3e32c55c    2669
# komistplay-i277fc4c38ac926c    1248
# 573880939902959083              440
# komistplay-i278aa7320f12d13     342
# 578274137794105583              268
# 574253038517356133              260
# komistplay-i27bfe4daaba1aa4     206
# 512399732703117729              163
# komistplay-i2748777614c52b2     158
# 576465400783883159              150
# 492786776143062094              120
# 578273416764105287              109
# komistplay-i272fc84fda669f3     108
# 282202902410497492               96
# 586206336715673895               86
# 568854315415129371               82
# 492787488847698857               71
# 576422175842834761               70
# 459856103233242576               65
# 381122606079794609               64
# 586205984360772448               63
# 497056817508328233               55
# 576417976967144256               48
# komistplay-i27abe6a50fb8529      44
# komistplay-i273dcf86faab892      44
# 489173088290878094               43
# 578596448757830182               42
# 568854641757307119               42
# 578596649534875174               42
# 568853918193827296               41
#                                ...
# 620323534698643516                1
# 586206498062409472                1
# 590853921938221590                1
# 587586186663967653                1
# 623413306665067448                1
# 593605176238666497                1
# 605124589001307087                1
# 618866435523502847                1
# 589924698926990719                1
# 615639312893166031                1
# 593070865449698631                1
# 617245503348298682                1
# 603714064828635124                1
# 605082093214957364                1
# 610153002577648734                1
# 459851089169425063                1
# 610389395996344353                1
# 589201859802427818                1
# 620100254725105453                1
# 623499199228884375                1
# 595195749714078946                1
# 609253593853803627                1
# 619223104438557299                1
# 600431158752622077                1
# 606250367277702445                1
# 587485019157943717                1
# 609445163144183502                1
# 554645171573317162                1
# 595456461032105134                1
# 627086592795994386                1
# Name: x24, Length: 440, dtype: int64

# %% [markdown]
# ### x25
# Referral

# %%
data['x25'].value_counts()
# Out:
# Facebook                 2930
# Bidalgo - Facebook       2669
# Bidalgo - Instagram      1248
# Fluent                    342
# YouTube                   192
# Google Adwords            158
# Fyber - Android           127
# UnityAds - Android        108
# Snapchat                   17
# Youtube                    15
# Bidalgo - Snapchat         15
# YeahMobi                   12
# AppLovin - Android          9
# App Samurai - Android       9
# Instagram                   6
# S1bVnL4qM                   5
# TapJoy - Android            5
# rJCLgqHf7                   3
# HWy431lw4                   3
# U6APtP6dD                   3
# HJY9lKXvG                   3
# CxssTFyT8                   3
# ByjV5rZXX                   2
# 9bCZTf5KH                   2
# PN71L5oPo                   2
# Bk-o2n2Ff                   2
# XXFwmxgUJ                   2
# inVKh7F11                   2
# gNwQLYK4P                   2
# Cm51jQuEs                   2
#                          ...
# rkjvAbX_M                   1
# IKBORstWN                   1
# TVOSFcsXq                   1
# BI-gFpQDl                   1
# uwdK17AJC                   1
# u2iTWjLhz                   1
# w3cOqxJIs                   1
# oXLTO4ahX                   1
# Lh08rr1pb                   1
# _2hfTo6hk                   1
# ByGV-UO5f                   1
# RIBWhuCm5                   1
# r1DFp2fMQ                   1
# ZHAOnN4hW                   1
# S1XVtF37M                   1
# EnfxiBq88                   1
# ryp9iwqgm                   1
# 6xIne0YMS                   1
# x58TmdGen                   1
# xXnfH5SIs                   1
# ikfS8rpW1                   1
# cupRR-hl0                   1
# ZjQCUsS60                   1
# Nq7KxDgD9                   1
# VNZizH-UF                   1
# ywtxBHnH_                   1
# oXWS-REpH                   1
# vCLlMvhb3                   1
# uOt1dL_n8                   1
# 7U_vSGtpv                   1
# Name: x25, Length: 360, dtype: int64

# %% [markdown]
# ### x26
# Campaign?

# %%
data['x26'].value_counts()
# Out:
# Bidalgo Facebook                    2669
# Default Facebook                    1257
# Play Games. Earn Money.              566
# Fortnite                             455
# LLC                                  342
# Amazon                               290
# Play Games Earn Money                269
# Gamer Giftcards                      259
# Copy Tests                           224
# Facebook                             207
# Google UAC                           158
# Fyber                                127
# Unity                                108
# Pirate Kings                         101
# Yahtzee                               97
# Mistplay Android/iOS                  97
# Clash of Clans                        80
# Starbucks                             54
# Lookalike                             43
# Campaign 2018-10-05 12:10:35:839      43
# Gamer GIftcards                       40
# Discover New Games                    36
# Snapchat                              32
# Clash Royale                          24
# Spiele Spielen                        18
# Final Fantasy                         13
# Yeahmobi                              12
# Appsamurai                             9
# Applovin_EN                            9
# Copy tests                             6
# Tapjoy                                 5
# Pokemon                                3
# Knights and Dragons                    2
# Easy as 1                              1
# Youtube Contest                        1
# WWE                                    1
# Name: x26, dtype: int64

# %% [markdown]
# ## Training

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate, GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score


# helper functions 
def print_metrics(y_true, y_predicted, y_predicted_proba):
    print(classification_report(y_true, y_predicted))
    print(confusion_matrix(y_true, y_predicted))
    print('AUC', roc_auc_score(y_true, y_predicted_proba))
    

def train(preditors, target, model):
    '''
    a small wraper to train model given predictors X and target y
    
    Print out after training
    
    Returns:
    [int] predicted class
    [float] predicted_prob for the class 1
        
    '''
    model.fit(preditors, target)
    predicted = model.predict(preditors)
    predicted_prob = model.predict_proba(preditors)[:,1]
    print_metrics(target, predicted, predicted_prob)
    return predicted, predicted_prob

def train_cv(preditors, target, model, cv=None):
    '''
    train model with CV
    
    print out metrics for each fold
    
    Returns:
    [float] roc_auc_score for the test set
    '''
    scores = np.array([])
    
    cv = cv if cv is not None else StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    for i, j in cv.split(preditors, target):
        Xi, yi = preditors.iloc[i], target[i]
        Xj, yj = preditors.iloc[j], target[j]
        
        model.fit(Xi, yi)
    
        predicted = model.predict(Xj)
        predicted_prob = model.predict_proba(Xj)[:,1]
    
        scores = np.append(scores, roc_auc_score(yj, predicted_prob))
        print_metrics(yj, predicted, predicted_prob)

    print(scores, '--', scores.mean(), scores.std())
    
    return scores

# %%
X = data.copy().drop(data.select_dtypes('object').columns, 1).drop(['y', 'x6', 'Unnamed: 28'], 1)

X['x7'] = X['x7'] / 100
X['x14'] = X['x14'] / 1000

# %% [markdown]
# ### LR
#
# Starting with Linear Regression, using numeric features only. Then add categaorical features one by one

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      9850
#           1       0.03      0.65      0.05       150
#
# avg / total       0.98      0.64      0.77     10000
#
# [[6326 3524]
#  [  53   97]]
# AUC 0.6960940778341793
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1316  654]
#  [  11   19]]
# AUC 0.6761928934010152
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.65      0.77      2000
#
# [[1273  697]
#  [  11   19]]
# AUC 0.7042131979695432
#              precision    recall  f1-score   support
#
#           0       0.99      0.61      0.76      1970
#           1       0.02      0.63      0.05        30
#
# avg / total       0.98      0.61      0.75      2000
#
# [[1209  761]
#  [  11   19]]
# AUC 0.6837901861252115
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.02      0.47      0.04        30
#
# avg / total       0.97      0.66      0.79      2000
#
# [[1314  656]
#  [  16   14]]
# AUC 0.5590862944162437
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.02      0.53      0.04        30
#
# avg / total       0.97      0.64      0.77      2000
#
# [[1261  709]
#  [  14   16]]
# AUC 0.6380879864636209
# [0.67619289 0.7042132  0.68379019 0.55908629 0.63808799] -- 0.6522741116751268 0.05128012321959517

# %% [markdown]
# #### x2

# %%
tmp = pd.get_dummies(data['x2'].str[0], prefix='x2') # only take the major version
# data.groupby(data['x2'].str[0])['y'].agg(['sum', 'size'])
X['x2_6'] = tmp['x2_6']
X['x2_7'] = tmp['x2_7']
X['x2_8'] = tmp['x2_8']
X['x2_9'] = tmp['x2_9']

model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model); # a bit better
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      9850
#           1       0.03      0.65      0.05       150
#
# avg / total       0.98      0.64      0.77     10000
#
# [[6326 3524]
#  [  53   97]]
# AUC 0.6960940778341793
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1316  654]
#  [  11   19]]
# AUC 0.6761928934010152
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.65      0.77      2000
#
# [[1273  697]
#  [  11   19]]
# AUC 0.7042131979695432
#              precision    recall  f1-score   support
#
#           0       0.99      0.61      0.76      1970
#           1       0.02      0.63      0.05        30
#
# avg / total       0.98      0.61      0.75      2000
#
# [[1209  761]
#  [  11   19]]
# AUC 0.6837901861252115
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.02      0.47      0.04        30
#
# avg / total       0.97      0.66      0.79      2000
#
# [[1314  656]
#  [  16   14]]
# AUC 0.5590862944162437
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.02      0.53      0.04        30
#
# avg / total       0.97      0.64      0.77      2000
#
# [[1261  709]
#  [  14   16]]
# AUC 0.6380879864636209
# [0.67619289 0.7042132  0.68379019 0.55908629 0.63808799] -- 0.6522741116751268 0.05128012321959517

# %% [markdown]
# #### x4

# %%
tmp = pd.get_dummies(data['x4'].str.lower().str[:2], prefix='x4') # language, take the first 2 letter
for i in tmp[tmp.sum().sort_values()[:-11:-1].index.values]:
    X[i] = tmp[i]
    
model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      9850
#           1       0.03      0.69      0.06       150
#
# avg / total       0.98      0.65      0.78     10000
#
# [[6439 3411]
#  [  46  104]]
# AUC 0.7195526226734349
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.02      0.53      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1323  647]
#  [  14   16]]
# AUC 0.6674111675126904
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.65      0.78      2000
#
# [[1288  682]
#  [  12   18]]
# AUC 0.678984771573604
#              precision    recall  f1-score   support
#
#           0       0.99      0.63      0.77      1970
#           1       0.03      0.70      0.05        30
#
# avg / total       0.98      0.63      0.76      2000
#
# [[1245  725]
#  [   9   21]]
# AUC 0.7106091370558376
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.02      0.50      0.04        30
#
# avg / total       0.97      0.65      0.77      2000
#
# [[1275  695]
#  [  15   15]]
# AUC 0.5805752961082911
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.65      0.78      2000
#
# [[1284  686]
#  [  12   18]]
# AUC 0.6406260575296108
# [0.66741117 0.67898477 0.71060914 0.5805753  0.64062606] -- 0.6556412859560068 0.043738479634492816

# %% [markdown]
# #### x5

# %%
tmp = pd.get_dummies(data['x5'].str.lower(), prefix='x5')
for i in tmp[tmp.sum().sort_values()[1:].index.values]:
    X[i] = tmp[i]


model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      9850
#           1       0.03      0.69      0.06       150
#
# avg / total       0.98      0.65      0.78     10000
#
# [[6432 3418]
#  [  47  103]]
# AUC 0.719805752961083
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.02      0.53      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1328  642]
#  [  14   16]]
# AUC 0.668984771573604
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      1970
#           1       0.02      0.57      0.05        30
#
# avg / total       0.98      0.65      0.78      2000
#
# [[1291  679]
#  [  13   17]]
# AUC 0.6732656514382402
#              precision    recall  f1-score   support
#
#           0       0.99      0.63      0.77      1970
#           1       0.03      0.70      0.05        30
#
# avg / total       0.98      0.63      0.76      2000
#
# [[1244  726]
#  [   9   21]]
# AUC 0.7120981387478851
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.02      0.47      0.04        30
#
# avg / total       0.97      0.64      0.77      2000
#
# [[1274  696]
#  [  16   14]]
# AUC 0.5737055837563452
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.65      0.77      2000
#
# [[1283  687]
#  [  12   18]]
# AUC 0.6419627749576988
# [0.66898477 0.67326565 0.71209814 0.57370558 0.64196277] -- 0.6540033840947547 0.04596344295152221

# %% [markdown]
# #### x8

# %%
tmp = pd.get_dummies(data['x8'].str.lower(), prefix='x8')
for i in tmp[tmp.sum().sort_values()[1:].index.values]:
    X[i] = tmp[i]

model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      9850
#           1       0.03      0.69      0.06       150
#
# avg / total       0.98      0.65      0.78     10000
#
# [[6433 3417]
#  [  47  103]]
# AUC 0.7198693739424704
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.02      0.53      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1326  644]
#  [  14   16]]
# AUC 0.6684433164128595
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      1970
#           1       0.02      0.57      0.05        30
#
# avg / total       0.98      0.65      0.78      2000
#
# [[1290  680]
#  [  13   17]]
# AUC 0.6728764805414552
#              precision    recall  f1-score   support
#
#           0       0.99      0.63      0.77      1970
#           1       0.03      0.70      0.05        30
#
# avg / total       0.98      0.63      0.76      2000
#
# [[1243  727]
#  [   9   21]]
# AUC 0.7119627749576989
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.02      0.47      0.04        30
#
# avg / total       0.97      0.65      0.77      2000
#
# [[1277  693]
#  [  16   14]]
# AUC 0.5739424703891709
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.65      0.77      2000
#
# [[1283  687]
#  [  12   18]]
# AUC 0.6418781725888326
# [0.66844332 0.67287648 0.71196277 0.57394247 0.64187817] -- 0.6538206429780035 0.04578340330272307

# %% [markdown]
# #### x15

# %%
tmp = pd.get_dummies(data['x15'].str.lower(), prefix='x15')
for i in tmp[tmp.sum().sort_values()[:-11:-1].index.values]:
    X[i] = tmp[i]

model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      9850
#           1       0.03      0.71      0.06       150
#
# avg / total       0.98      0.66      0.78     10000
#
# [[6463 3387]
#  [  44  106]]
# AUC 0.7413617597292725
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.57      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1329  641]
#  [  13   17]]
# AUC 0.6805076142131979
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.65      0.77      2000
#
# [[1276  694]
#  [  12   18]]
# AUC 0.681082910321489
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.02      0.60      0.05        30
#
# avg / total       0.98      0.64      0.77      2000
#
# [[1265  705]
#  [  12   18]]
# AUC 0.7052791878172588
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.02      0.50      0.04        30
#
# avg / total       0.97      0.64      0.77      2000
#
# [[1268  702]
#  [  15   15]]
# AUC 0.5908460236886632
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.57      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1313  657]
#  [  13   17]]
# AUC 0.6392893401015228
# [0.68050761 0.68108291 0.70527919 0.59084602 0.63928934] -- 0.6594010152284264 0.040310460570547546

# %% [markdown]
# #### x16

# %%
tmp = pd.get_dummies(data['x16'].str.lower(), prefix='x16')
for i in tmp[tmp.sum().sort_values()[1:].index.values]:
    X[i] = tmp[i]
    

model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
# x16_1
# x16_0
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      9850
#           1       0.03      0.74      0.06       150
#
# avg / total       0.98      0.66      0.78     10000
#
# [[6490 3360]
#  [  39  111]]
# AUC 0.7457516074450085
#              precision    recall  f1-score   support
#
#           0       0.99      0.68      0.80      1970
#           1       0.03      0.57      0.05        30
#
# avg / total       0.98      0.68      0.79      2000
#
# [[1334  636]
#  [  13   17]]
# AUC 0.6893570219966159
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.66      0.78      2000
#
# [[1294  676]
#  [  11   19]]
# AUC 0.6884940778341793
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.64      0.77      2000
#
# [[1256  714]
#  [  11   19]]
# AUC 0.7036717428087986
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.02      0.50      0.04        30
#
# avg / total       0.97      0.65      0.77      2000
#
# [[1279  691]
#  [  15   15]]
# AUC 0.5910490693739424
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1316  654]
#  [  12   18]]
# AUC 0.6392893401015228
# [0.68935702 0.68849408 0.70367174 0.59104907 0.63928934] -- 0.6623722504230118 0.04179950415823209

# %% [markdown]
# #### x17

# %%
tmp = pd.get_dummies(data['x17'].str.lower(), prefix='x17')
for i in tmp[tmp.sum().sort_values()[1:].index.values]:
    X[i] = tmp[i]
    
model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      9850
#           1       0.03      0.75      0.06       150
#
# avg / total       0.98      0.66      0.78     10000
#
# [[6484 3366]
#  [  38  112]]
# AUC 0.747306937394247
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.57      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1317  653]
#  [  13   17]]
# AUC 0.6898477157360406
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.65      0.78      2000
#
# [[1290  680]
#  [  11   19]]
# AUC 0.6899830795262267
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.64      0.76      2000
#
# [[1254  716]
#  [  11   19]]
# AUC 0.7015736040609136
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.02      0.50      0.04        30
#
# avg / total       0.97      0.65      0.77      2000
#
# [[1278  692]
#  [  15   15]]
# AUC 0.5862098138747885
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1315  655]
#  [  12   18]]
# AUC 0.6405076142131979
# [0.68984772 0.68998308 0.7015736  0.58620981 0.64050761] -- 0.6616243654822335 0.043197193434538435

# %% [markdown]
# #### x23

# %%
tmp = pd.get_dummies(data['x23'].str.lower(), prefix='x23')
for i in tmp[tmp.sum().sort_values()[1:].index.values]:
    X[i] = tmp[i]

model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      9850
#           1       0.03      0.74      0.06       150
#
# avg / total       0.98      0.66      0.78     10000
#
# [[6475 3375]
#  [  39  111]]
# AUC 0.7478693739424703
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.57      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1326  644]
#  [  13   17]]
# AUC 0.69331641285956
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      1970
#           1       0.03      0.67      0.06        30
#
# avg / total       0.98      0.66      0.78      2000
#
# [[1294  676]
#  [  10   20]]
# AUC 0.6825888324873096
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.02      0.60      0.05        30
#
# avg / total       0.98      0.64      0.76      2000
#
# [[1256  714]
#  [  12   18]]
# AUC 0.7051945854483925
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      1970
#           1       0.02      0.53      0.04        30
#
# avg / total       0.97      0.65      0.78      2000
#
# [[1286  684]
#  [  14   16]]
# AUC 0.5836209813874789
#              precision    recall  f1-score   support
#
#           0       0.99      0.68      0.80      1970
#           1       0.03      0.63      0.06        30
#
# avg / total       0.98      0.68      0.79      2000
#
# [[1333  637]
#  [  11   19]]
# AUC 0.6431302876480542
# [0.69331641 0.68258883 0.70519459 0.58362098 0.64313029] -- 0.661570219966159 0.04420136422817527

# %% [markdown]
# #### x24

# %%
tmp = pd.get_dummies(data['x24'].fillna('').str.lower().str[:2], prefix='x24')
for i in tmp[tmp.sum().sort_values()[:-11:-1].index.values]:
    X[i] = tmp[i]
    

model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      9850
#           1       0.03      0.73      0.06       150
#
# avg / total       0.98      0.65      0.77     10000
#
# [[6400 3450]
#  [  40  110]]
# AUC 0.7540480541455162
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      1970
#           1       0.02      0.57      0.05        30
#
# avg / total       0.98      0.66      0.78      2000
#
# [[1297  673]
#  [  13   17]]
# AUC 0.6868697123519459
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.80      1970
#           1       0.03      0.67      0.06        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1310  660]
#  [  10   20]]
# AUC 0.6789340101522843
#              precision    recall  f1-score   support
#
#           0       0.99      0.63      0.77      1970
#           1       0.02      0.60      0.05        30
#
# avg / total       0.98      0.63      0.76      2000
#
# [[1239  731]
#  [  12   18]]
# AUC 0.7019966159052454
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.02      0.50      0.04        30
#
# avg / total       0.97      0.64      0.77      2000
#
# [[1266  704]
#  [  15   15]]
# AUC 0.5774619289340102
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.66      0.79      2000
#
# [[1311  659]
#  [  12   18]]
# AUC 0.6486802030456853
# [0.68686971 0.67893401 0.70199662 0.57746193 0.6486802 ] -- 0.6587884940778342 0.04422109491000855

# %% [markdown]
# #### x25

# %%
tmp = pd.get_dummies(data['x25'].fillna('').str.lower(), prefix='x25')
for i in tmp[tmp.sum().sort_values()[:-11:-1].index.values]:
    X[i] = tmp[i]
    
model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      9850
#           1       0.03      0.77      0.06       150
#
# avg / total       0.98      0.65      0.78     10000
#
# [[6426 3424]
#  [  34  116]]
# AUC 0.7608013536379018
#              precision    recall  f1-score   support
#
#           0       0.99      0.66      0.79      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.66      0.78      2000
#
# [[1296  674]
#  [  12   18]]
# AUC 0.6969543147208122
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.63      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1325  645]
#  [  11   19]]
# AUC 0.6890186125211506
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.02      0.53      0.04        30
#
# avg / total       0.97      0.64      0.76      2000
#
# [[1256  714]
#  [  14   16]]
# AUC 0.6777326565143824
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.02      0.47      0.04        30
#
# avg / total       0.97      0.64      0.77      2000
#
# [[1274  696]
#  [  16   14]]
# AUC 0.5512859560067681
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1320  650]
#  [  12   18]]
# AUC 0.6556175972927243
# [0.69695431 0.68901861 0.67773266 0.55128596 0.6556176 ] -- 0.6541218274111674 0.053267875133376906

# %% [markdown]
# #### x26

# %%
tmp = data['x26'].str.lower().replace(to_replace='.*facebook.*', value='facebook', regex=True)
tmp = tmp.replace(to_replace='.*play games.*', value='play games earn money', regex=True)
tmp = pd.get_dummies(tmp, prefix='x26')
for i in tmp[tmp.sum().sort_values().sort_values()[:-11:-1].index.values]:
    X[i] = tmp[i]


model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

train(X, y, model);
train_cv(X, y, model);
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.65      0.79      9850
#           1       0.03      0.80      0.06       150
#
# avg / total       0.98      0.65      0.77     10000
#
# [[6386 3464]
#  [  30  120]]
# AUC 0.7646869712351945
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.03      0.67      0.05        30
#
# avg / total       0.98      0.65      0.77      2000
#
# [[1279  691]
#  [  10   20]]
# AUC 0.7013536379018612
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1316  654]
#  [  12   18]]
# AUC 0.682994923857868
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.77      1970
#           1       0.02      0.53      0.04        30
#
# avg / total       0.97      0.63      0.76      2000
#
# [[1252  718]
#  [  14   16]]
# AUC 0.6741962774957699
#              precision    recall  f1-score   support
#
#           0       0.99      0.64      0.78      1970
#           1       0.02      0.47      0.04        30
#
# avg / total       0.97      0.64      0.77      2000
#
# [[1263  707]
#  [  16   14]]
# AUC 0.5369035532994924
#              precision    recall  f1-score   support
#
#           0       0.99      0.67      0.80      1970
#           1       0.03      0.57      0.05        30
#
# avg / total       0.98      0.67      0.79      2000
#
# [[1316  654]
#  [  13   17]]
# AUC 0.658155668358714
# [0.70135364 0.68299492 0.67419628 0.53690355 0.65815567] -- 0.650720812182741 0.05859359060927814

# %% [markdown]
# #### Corr
# Individually, each var is not much correlated with y
#
# However, a few vars are highly correlated with each other, such as:
# - x5_1 and x20
# - x4_fr and x22, maybe x22 is "speaking French?"

# %%
pd.concat([pd.DataFrame({ 'y': y }), X], 1).corr(method='pearson').style.format('{:.2}').background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col1 {
#             background-color:  #92b4fe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col2 {
#             background-color:  #779af7;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col3 {
#             background-color:  #799cf8;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col4 {
#             background-color:  #8badfd;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col5 {
#             background-color:  #5f7fe8;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col6 {
#             background-color:  #b6cefa;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col7 {
#             background-color:  #8caffe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col8 {
#             background-color:  #c1d4f4;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col9 {
#             background-color:  #dcdddd;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col10 {
#             background-color:  #dfdbd9;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col11 {
#             background-color:  #cad8ef;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col12 {
#             background-color:  #7597f6;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col13 {
#             background-color:  #97b8ff;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col14 {
#             background-color:  #bfd3f6;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col15 {
#             background-color:  #c3d5f4;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col16 {
#             background-color:  #7699f6;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col17 {
#             background-color:  #7396f5;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col18 {
#             background-color:  #6a8bef;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col19 {
#             background-color:  #8fb1fe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col20 {
#             background-color:  #8fb1fe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col21 {
#             background-color:  #92b4fe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col22 {
#             background-color:  #7a9df8;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col23 {
#             background-color:  #7396f5;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col24 {
#             background-color:  #7a9df8;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col25 {
#             background-color:  #6e90f2;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col26 {
#             background-color:  #6f92f3;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col27 {
#             background-color:  #6b8df0;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col28 {
#             background-color:  #dfdbd9;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col29 {
#             background-color:  #d5dbe5;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col30 {
#             background-color:  #5572df;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col31 {
#             background-color:  #7da0f9;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col32 {
#             background-color:  #d9dce1;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col33 {
#             background-color:  #dadce0;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col34 {
#             background-color:  #a2c1ff;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col35 {
#             background-color:  #9dbdff;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col36 {
#             background-color:  #8db0fe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col37 {
#             background-color:  #7da0f9;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col38 {
#             background-color:  #7093f3;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col39 {
#             background-color:  #5f7fe8;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col40 {
#             background-color:  #5977e3;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col41 {
#             background-color:  #6485ec;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col42 {
#             background-color:  #5f7fe8;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col43 {
#             background-color:  #5572df;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col44 {
#             background-color:  #dddcdc;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col45 {
#             background-color:  #dbdcde;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col46 {
#             background-color:  #5470de;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col47 {
#             background-color:  #7093f3;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col48 {
#             background-color:  #7699f6;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col49 {
#             background-color:  #97b8ff;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col50 {
#             background-color:  #bfd3f6;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col51 {
#             background-color:  #c3d5f4;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col52 {
#             background-color:  #dadce0;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col53 {
#             background-color:  #dfdbd9;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col54 {
#             background-color:  #b2ccfb;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col55 {
#             background-color:  #a3c2fe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col56 {
#             background-color:  #9bbcff;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col57 {
#             background-color:  #6a8bef;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col58 {
#             background-color:  #6b8df0;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col59 {
#             background-color:  #6485ec;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col60 {
#             background-color:  #5977e3;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col61 {
#             background-color:  #536edd;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col62 {
#             background-color:  #5673e0;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col63 {
#             background-color:  #5572df;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col64 {
#             background-color:  #abc8fd;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col65 {
#             background-color:  #9dbdff;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col66 {
#             background-color:  #a3c2fe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col67 {
#             background-color:  #7a9df8;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col68 {
#             background-color:  #6384eb;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col69 {
#             background-color:  #5d7ce6;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col70 {
#             background-color:  #5875e1;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col71 {
#             background-color:  #506bda;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col72 {
#             background-color:  #516ddb;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col73 {
#             background-color:  #4961d2;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col74 {
#             background-color:  #a7c5fe;
#         }    #T_f0f156c6_5646_11e9_a397_0242ac1c0002row0_col75 {
#             background-color:  #85a8fc;
#         }

# %%
# what if using only cat variables. Results not as good

# tmp = X[X.columns[~X.columns.str.contains('_')]]
tmp = X[X.columns[X.columns.str.contains('_')]]
# tmp = X

model = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')

print(tmp.shape)
train(tmp, y, model)
print('===')
train_cv(tmp, y, model)
# Out:
# (10000, 71)
#              precision    recall  f1-score   support
#
#           0       0.99      0.57      0.73      9850
#           1       0.03      0.76      0.05       150
#
# avg / total       0.98      0.57      0.72     10000
#
# [[5624 4226]
#  [  36  114]]
# AUC 0.7274744500846024
# ===
#              precision    recall  f1-score   support
#
#           0       0.99      0.56      0.71      1970
#           1       0.02      0.67      0.04        30
#
# avg / total       0.98      0.56      0.70      2000
#
# [[1100  870]
#  [  10   20]]
# AUC 0.6654483925549914
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.79      1970
#           1       0.02      0.50      0.04        30
#
# avg / total       0.97      0.65      0.78      2000
#
# [[1286  684]
#  [  15   15]]
# AUC 0.6313451776649746
#              precision    recall  f1-score   support
#
#           0       0.99      0.58      0.73      1970
#           1       0.02      0.53      0.04        30
#
# avg / total       0.97      0.58      0.72      2000
#
# [[1138  832]
#  [  14   16]]
# AUC 0.6362267343485618
#              precision    recall  f1-score   support
#
#           0       0.99      0.61      0.75      1970
#           1       0.02      0.47      0.03        30
#
# avg / total       0.97      0.61      0.74      2000
#
# [[1199  771]
#  [  16   14]]
# AUC 0.5084517766497462
#              precision    recall  f1-score   support
#
#           0       0.99      0.59      0.74      1970
#           1       0.02      0.63      0.04        30
#
# avg / total       0.98      0.60      0.73      2000
#
# [[1172  798]
#  [  11   19]]
# AUC 0.6480795262267344
# [0.66544839 0.63134518 0.63622673 0.50845178 0.64807953] -- 0.6179103214890016 0.05597715336460147
# array([0.66544839, 0.63134518, 0.63622673, 0.50845178, 0.64807953])

# %% [markdown]
# ## GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

train(X, y, model)
print('===')
train_cv(X, y, model);

# better recall for class 1, but lower recall for class 0
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.16      0.27      9850
#           1       0.02      0.99      0.03       150
#
# avg / total       0.98      0.17      0.27     10000
#
# [[1551 8299]
#  [   1  149]]
# AUC 0.5996148900169205
# ===
#              precision    recall  f1-score   support
#
#           0       1.00      0.15      0.26      1970
#           1       0.02      0.97      0.03        30
#
# avg / total       0.98      0.16      0.26      2000
#
# [[ 295 1675]
#  [   1   29]]
# AUC 0.5925042301184433
#              precision    recall  f1-score   support
#
#           0       1.00      0.15      0.26      1970
#           1       0.02      1.00      0.03        30
#
# avg / total       0.99      0.16      0.26      2000
#
# [[ 293 1677]
#  [   0   30]]
# AUC 0.5964636209813874
#              precision    recall  f1-score   support
#
#           0       1.00      0.11      0.20      1970
#           1       0.02      0.97      0.03        30
#
# avg / total       0.98      0.12      0.20      2000
#
# [[ 219 1751]
#  [   1   29]]
# AUC 0.5716497461928934
#              precision    recall  f1-score   support
#
#           0       0.98      0.23      0.38      1970
#           1       0.01      0.77      0.03        30
#
# avg / total       0.97      0.24      0.37      2000
#
# [[ 459 1511]
#  [   7   23]]
# AUC 0.49959390862944164
#              precision    recall  f1-score   support
#
#           0       0.99      0.17      0.28      1970
#           1       0.02      0.93      0.03        30
#
# avg / total       0.98      0.18      0.28      2000
#
# [[ 327 1643]
#  [   2   28]]
# AUC 0.5794416243654823
# [0.59250423 0.59646362 0.57164975 0.49959391 0.57944162] -- 0.5679306260575295 0.03531072273783347

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=0, class_weight='balanced')

train(X, y, model)
print('===')
train_cv(X, y, model); # very bad CV
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      9850
#           1       1.00      1.00      1.00       150
#
# avg / total       1.00      1.00      1.00     10000
#
# [[9850    0]
#  [   0  150]]
# AUC 1.0
# ===
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1970    0]
#  [  30    0]]
# AUC 0.5770473773265652
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1970    0]
#  [  30    0]]
# AUC 0.5553722504230119
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1970    0]
#  [  30    0]]
# AUC 0.5590609137055838
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1970    0]
#  [  30    0]]
# AUC 0.5390016920473774
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1970    0]
#  [  30    0]]
# AUC 0.5473604060913706
# [0.57704738 0.55537225 0.55906091 0.53900169 0.54736041] -- 0.5555685279187818 0.012770352931263225
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## KNN
#
# bad, not run

# %%
# from sklearn.neighbors import KNeighborsClassifier

# model = KNeighborsClassifier(20, weights='distance')

# train(X, y, model)
# print('===')
# train_cv(X, y, model);

# %% [markdown]
# ## MLPClassifier
# Took too long, results were no good, so not run

# %%
# from sklearn.neural_network import MLPClassifier

# model = MLPClassifier(random_state=0)

# train(X, y, model)
# print('===')
# train_cv(X, y, model);

# %% [markdown]
# ## GaussianProcessClassifier
# Took too long, not run

# %%
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF

# model = GaussianProcessClassifier(kernel=1.0 * RBF(1.0), random_state=0)

# train(X, y, model)
# print('===')
# train_cv(X, y, model)

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier(random_state=0)

train(X, y, model)
print('===')
train_cv(X, y, model); # bad cv, overfit
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      9850
#           1       0.33      0.01      0.01       150
#
# avg / total       0.98      0.98      0.98     10000
#
# [[9848    2]
#  [ 149    1]]
# AUC 0.8219424703891709
# ===
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1970    0]
#  [  30    0]]
# AUC 0.6685109983079526
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1968    2]
#  [  30    0]]
# AUC 0.5818104906937395
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1970    0]
#  [  30    0]]
# AUC 0.6852115059221658
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1970    0]
#  [  30    0]]
# AUC 0.5714551607445009
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.98      0.98      2000
#
# [[1969    1]
#  [  30    0]]
# AUC 0.7134517766497461
# [0.668511   0.58181049 0.68521151 0.57145516 0.71345178] -- 0.6440879864636211 0.057013992318556604
# array([0.668511  , 0.58181049, 0.68521151, 0.57145516, 0.71345178])

# %% [markdown]
# ## QuadraticDiscriminantAnalysis

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

model = QuadraticDiscriminantAnalysis()

train(X, y, model)
print('===')
train_cv(X, y, model); # variables detected collinear, bad CV
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:682: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
#              precision    recall  f1-score   support
#
#           0       1.00      0.17      0.29      9850
#           1       0.02      0.99      0.04       150
#
# avg / total       0.98      0.18      0.29     10000
#
# [[1680 8170]
#  [   1  149]]
# AUC 0.5883620981387478
# ===
#              precision    recall  f1-score   support
#
#           0       0.99      0.17      0.29      1970
#           1       0.02      0.93      0.03        30
#
# avg / total       0.98      0.18      0.28      2000
#
# [[ 332 1638]
#  [   2   28]]
# AUC 0.5279526226734349
#              precision    recall  f1-score   support
#
#           0       1.00      0.14      0.24      1970
#           1       0.02      1.00      0.03        30
#
# avg / total       0.99      0.15      0.24      2000
#
# [[ 274 1696]
#  [   0   30]]
# AUC 0.5730964467005076
#              precision    recall  f1-score   support
#
#           0       0.99      0.25      0.39      1970
#           1       0.02      0.87      0.03        30
#
# avg / total       0.98      0.26      0.39      2000
#
# [[ 484 1486]
#  [   4   26]]
# AUC 0.5628426395939086
#              precision    recall  f1-score   support
#
#           0       0.98      0.26      0.41      1970
#           1       0.01      0.67      0.03        30
#
# avg / total       0.97      0.26      0.40      2000
#
# [[ 505 1465]
#  [  10   20]]
# AUC 0.46150592216582065
#              precision    recall  f1-score   support
#
#           0       1.00      0.12      0.21      1970
#           1       0.02      1.00      0.03        30
#
# avg / total       0.99      0.13      0.21      2000
#
# [[ 232 1738]
#  [   0   30]]
# AUC 0.5588832487309645
# [0.52795262 0.57309645 0.56284264 0.46150592 0.55888325] -- 0.5368561759729273 0.04057284672874965
# array([0.52795262, 0.57309645, 0.56284264, 0.46150592, 0.55888325])

# %% [markdown]
# ## SVC
#
# Very slow,
#
# LinearSVC also doesn't support predict_prob

# %%
# from sklearn.svm import SVC

# model = SVC(gamma='scale', class_weight='balanced', probability=True, random_state=0)

# train(X, y, model)
# print('===')
# train_cv(X, y, model)

# %%
# from sklearn.svm import LinearSVC

# model = LinearSVC(max_iter=2000, class_weight='balanced', random_state=0)

# model.fit(X, y)
# train(X, y, model)
# print('===')
# train_cv(X, y, model)

# %% [markdown]
# ## SGDClassifier
#
# Also bad

# %%
# from sklearn.linear_model import SGDClassifier

# model = SGDClassifier(
#     loss='log',
#     max_iter=1000,
#     tol=1e-3,
#     class_weight='balanced',
#     random_state=0,
# )

# train(X, y, model)
# print('===')
# train_cv(X, y, model)

# %% [markdown]
# ## LGBM

# %%
from lightgbm import LGBMClassifier

model = LGBMClassifier(class_weight='balanced')

train(X, y, model)
print('===')
train_cv(X, y, model);
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       1.00      0.99      0.99      9850
#           1       0.51      1.00      0.68       150
#
# avg / total       0.99      0.99      0.99     10000
#
# [[9706  144]
#  [   0  150]]
# AUC 0.9999181049069374
# ===
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.97      0.97      2000
#
# [[1948   22]
#  [  30    0]]
# AUC 0.5473434856175974
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.97      0.97      2000
#
# [[1940   30]
#  [  30    0]]
# AUC 0.6092216582064298
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.98      0.98      1970
#           1       0.05      0.07      0.06        30
#
# avg / total       0.97      0.97      0.97      2000
#
# [[1935   35]
#  [  28    2]]
# AUC 0.603824027072758
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.97      0.97      2000
#
# [[1933   37]
#  [  30    0]]
# AUC 0.5810659898477157
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      1970
#           1       0.00      0.00      0.00        30
#
# avg / total       0.97      0.97      0.97      2000
#
# [[1942   28]
#  [  30    0]]
# AUC 0.5961590524534687
# [0.54734349 0.60922166 0.60382403 0.58106599 0.59615905] -- 0.587522842639594 0.022213612986427503
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([0.54734349, 0.60922166, 0.60382403, 0.58106599, 0.59615905])

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier

scale_pos_weight = np.sum(y == 0) / np.sum(y == 1)

model = XGBClassifier(n_jobs=-1, random_state=0, scale_pos_weight=scale_pos_weight)

train(X, y, model)
print('===')
train_cv(X, y, model);
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       1.00      0.77      0.87      9850
#           1       0.06      0.91      0.11       150
#
# avg / total       0.98      0.77      0.86     10000
#
# [[7560 2290]
#  [  13  137]]
# AUC 0.9240060913705584
# ===
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.81      0.89      1970
#           1       0.02      0.30      0.04        30
#
# avg / total       0.97      0.81      0.88      2000
#
# [[1601  369]
#  [  21    9]]
# AUC 0.6452707275803723
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.98      0.80      0.88      1970
#           1       0.01      0.17      0.02        30
#
# avg / total       0.97      0.79      0.87      2000
#
# [[1569  401]
#  [  25    5]]
# AUC 0.5925549915397631
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.77      0.86      1970
#           1       0.02      0.33      0.04        30
#
# avg / total       0.97      0.76      0.85      2000
#
# [[1510  460]
#  [  20   10]]
# AUC 0.6537140439932319
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.75      0.85      1970
#           1       0.02      0.27      0.03        30
#
# avg / total       0.97      0.74      0.84      2000
#
# [[1480  490]
#  [  22    8]]
# AUC 0.5695262267343485
#              precision    recall  f1-score   support
#
#           0       0.99      0.81      0.89      1970
#           1       0.03      0.37      0.05        30
#
# avg / total       0.97      0.80      0.88      2000
#
# [[1588  382]
#  [  19   11]]
# AUC 0.6518443316412859
# [0.64527073 0.59255499 0.65371404 0.56952623 0.65184433] -- 0.6225820642978004 0.034804605699143204
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([0.64527073, 0.59255499, 0.65371404, 0.56952623, 0.65184433])

# %% [markdown]
# ### Hyperopt
#
# Hyper parameter tuning with Baysian optimisation

# %%
from hyperopt import STATUS_OK
from hyperopt import fmin
from hyperopt import hp
from hyperopt.pyll.stochastic import sample
from hyperopt import tpe
from hyperopt import Trials

from timeit import default_timer as timer

import xgboost

xgtrain = xgboost.DMatrix(X.values, label=y)

def objective(params, folds = cv):
    """Objective function for Gradient Boosting Machine Hyperparameter Optimization"""
    
    # Keep track of evals
    global ITERATION
    
    ITERATION += 1
    
    start = timer()
    
    # Make sure parameters that need to be integers are integers
    for parameter_name in ['max_depth', 'min_child_weight']:
        params[parameter_name] = int(params[parameter_name])

    params['scale_pos_weight'] = scale_pos_weight
    params['verbosity'] = 0
    
    # Perform n_folds cross validation    
    cv_results = xgboost.cv(params, xgtrain, num_boost_round=10000, folds=folds,
        metrics='auc', early_stopping_rounds=50, seed=0)
    
    run_time = timer() - start
    
    # Extract the best score
    best_score = np.max(cv_results['test-auc-mean'])
    
    # Loss must be minimized
    loss = 1 - best_score
    
    # Boosting rounds that returned the highest cv score
    n_estimators = int(np.argmax(cv_results['test-auc-mean']) + 1)
    
#     print('\n\n=====', loss, params, ITERATION, n_estimators)


    # Write to the csv file ('a' means append)
#     of_connection = open('./gbm_trials.csv', 'a')
#     writer = csv.writer(of_connection)
#     writer.writerow([loss, params, ITERATION, n_estimators, run_time])
    
    # Dictionary with information for evaluation
    return {'loss': loss, 'params': params, 'iteration': ITERATION,
            'estimators': n_estimators, 
            'train_time': run_time, 'status': STATUS_OK}

# %%
# Keep track of results
bayes_trials = Trials()

# %%
# Global variable
global ITERATION

ITERATION = 0

# Define the search space
space = {
    'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.3)),
    'gamma': hp.uniform('gamma', 0, 1),
    'max_depth': hp.quniform('max_depth', 3, 8, 1),
    'min_child_weight': hp.quniform('min_child_weight', 1, 12, 2),
    'subsample': hp.uniform('subsample', 0.6, 1.0),
    'colsample_bytree': hp.uniform('colsample_by_tree', 0.6, 1.0),

#     'num_leaves': hp.quniform('num_leaves', 30, 150, 1),
#     'subsample_for_bin': hp.quniform('subsample_for_bin', 20000, 300000, 20000),
#     'min_child_samples': hp.quniform('min_child_samples', 20, 500, 5),
    'reg_alpha': hp.uniform('reg_alpha', 0.1, 10),
    'reg_lambda': hp.uniform('reg_lambda', 0.1, 10),
}

# Run optimization
best = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest, 
    max_evals=10000,
    trials=bayes_trials,
    rstate=np.random.RandomState(0)
);

# %%
# take a long time to train, so save the best param for next use
# import pickle

# with open('trials.pkl', 'wb') as handle:
#     pickle.dump(bayes_trials, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# # with open('trials.pickle', 'rb') as handle: bayes_trials = pickle.load(handle)

# bayes_trials.best_trial['result']

# %%
# best param
params = {
    'colsample_bytree': 0.9492405652889128,
    'gamma': 0.2174707094781907,
    'learning_rate': 0.2087465061696673,
    'max_depth': 4,
    'min_child_weight': 4,
    'reg_alpha': 0.4475446011595685,
    'reg_lambda': 0.16373566452669497,
    'scale_pos_weight': 65.66666666666667,
    'subsample': 0.781163089515965,
    'verbosity': 0,
    'scale_pos_weight': scale_pos_weight
}
model = XGBClassifier(n_jobs=-1, random_state=0, **params)


train(X, y, model)
print('===')
train_cv(X, y, model); # mmm, not that "best", still low recall
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       1.00      0.94      0.97      9850
#           1       0.21      1.00      0.34       150
#
# avg / total       0.99      0.94      0.96     10000
#
# [[9277  573]
#  [   0  150]]
# AUC 0.9958971235194585
# ===
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.96      0.97      1970
#           1       0.02      0.07      0.03        30
#
# avg / total       0.97      0.94      0.96      2000
#
# [[1883   87]
#  [  28    2]]
# AUC 0.5573096446700508
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.95      0.97      1970
#           1       0.03      0.10      0.04        30
#
# avg / total       0.97      0.93      0.95      2000
#
# [[1866  104]
#  [  27    3]]
# AUC 0.5272081218274112
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.94      0.96      1970
#           1       0.02      0.07      0.03        30
#
# avg / total       0.97      0.93      0.95      2000
#
# [[1861  109]
#  [  28    2]]
# AUC 0.6412013536379019
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.98      0.95      0.97      1970
#           1       0.01      0.03      0.02        30
#
# avg / total       0.97      0.93      0.95      2000
#
# [[1868  102]
#  [  29    1]]
# AUC 0.5733671742808798
#              precision    recall  f1-score   support
#
#           0       0.98      0.95      0.97      1970
#           1       0.01      0.03      0.02        30
#
# avg / total       0.97      0.94      0.95      2000
#
# [[1872   98]
#  [  29    1]]
# AUC 0.5651776649746193
# [0.55730964 0.52720812 0.64120135 0.57336717 0.56517766] -- 0.5728527918781725 0.03756520567238148
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([0.55730964, 0.52720812, 0.64120135, 0.57336717, 0.56517766])

# %% [markdown]
# ## Ensemble

# %%
model1 = LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')
model2 = XGBClassifier(n_jobs=-1, random_state=0, **params)
model3 = GaussianNB()
model4 = LinearSVC(max_iter=10000, class_weight='balanced', random_state=0, tol=0.0005)


model1.fit(X, y)
model2.fit(X, y)
model3.fit(X, y)
model4.fit(X, y)

pre1 = model1.predict(X)
preb1 = model1.predict_proba(X)[:,1]
pre2 = model2.predict(X)
preb2 = model2.predict_proba(X)[:,1]
pre3 = model3.predict(X)
preb3 = model3.predict_proba(X)[:,1]
pre4 = model4.predict(X)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# pre = np.where(pre1 + pre2 + pre3 + pre4 > 1, 1, 0)
# pre1.sum(), pre2.sum(), pre3.sum(), pre4.sum(), pre.sum()

# print(confusion_matrix(y, pre))

# pre = np.where(pre1 + pre2 + pre3 > 2, 1, 0)
# pre1.sum(), pre2.sum(), pre3.sum(), pre.sum()

# print(confusion_matrix(y, pre))


# pre = np.where(preb1 + preb2 + preb3 > 2, 1, 0)
# pre1.sum(), pre2.sum(), pre3.sum(), pre.sum()

# print(confusion_matrix(y, pre));
# Out:
# [[9384  466]
#  [  30  120]]
# [[8869  981]
#  [   4  146]]

# %%
pre = pd.DataFrame({
    'm1': pre1,
    'm2': pre2,
    'm3': pre3,
})

pre.corr(method='pearson') # good that they are not correlated
# Out:
#           m1        m2        m3
# m1  1.000000  0.263206  0.318043
# m2  0.263206  1.000000  0.115390
# m3  0.318043  0.115390  1.000000

# %%
from sklearn.ensemble import VotingClassifier


model = VotingClassifier(
    estimators=[
        ('model1', LogisticRegression(random_state=0, solver='lbfgs', max_iter=5000, class_weight='balanced')),
        ('model2', XGBClassifier(n_jobs=-1, random_state=0, **params)),
        ('model3', GaussianNB()),
#         ('model4', QuadraticDiscriminantAnalysis()),
#         ('model5', LGBMClassifier(class_weight='balanced'))
    ],
#     voting='hard',
#     voting='soft',
    voting='soft', weights=[10, 1, 1]
)


# tmp = X[X.columns[~X.columns.str.contains('_')]]
# tmp = X[X.columns[X.columns.str.contains('_')]]
# tmp = X[X.columns[~X.columns.str.contains('x17_|x25_|x22', regex=True)]]
tmp = X

print(tmp.shape)

# model.fit(tmp, y)
# print_all(y, model.predict(tmp), model.predict(tmp))
# scores = np.array([])
# for i, j in cv.split(X, y):
#     Xi, yi = X.iloc[i], y[i]
#     Xj, yj = X.iloc[j], y[j]
#     model.fit(Xi, yi)
#     predicted = model.predict(Xj)
#     scores = np.append(scores, roc_auc_score(yj, predicted))
#     print_all(yj, predicted, predicted)
# print(scores, '--', scores.mean(), scores.std())

    
train(tmp, y, model);
print('===')
train_cv(tmp, y, model);
# Out:
# (10000, 83)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       1.00      0.62      0.77      9850
#           1       0.03      0.89      0.07       150
#
# avg / total       0.98      0.63      0.76     10000
#
# [[6151 3699]
#  [  16  134]]
# AUC 0.8276805414551609
# ===
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.63      0.77      1970
#           1       0.03      0.67      0.05        30
#
# avg / total       0.98      0.63      0.76      2000
#
# [[1245  725]
#  [  10   20]]
# AUC 0.7001353637901861
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.03      0.60      0.05        30
#
# avg / total       0.98      0.65      0.77      2000
#
# [[1277  693]
#  [  12   18]]
# AUC 0.679746192893401
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.62      0.76      1970
#           1       0.02      0.63      0.05        30
#
# avg / total       0.98      0.62      0.75      2000
#
# [[1221  749]
#  [  11   19]]
# AUC 0.6765482233502538
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#              precision    recall  f1-score   support
#
#           0       0.99      0.63      0.77      1970
#           1       0.02      0.50      0.04        30
#
# avg / total       0.97      0.63      0.76      2000
#
# [[1236  734]
#  [  15   15]]
# AUC 0.5398984771573604
#              precision    recall  f1-score   support
#
#           0       0.99      0.65      0.78      1970
#           1       0.02      0.57      0.05        30
#
# avg / total       0.98      0.64      0.77      2000
#
# [[1272  698]
#  [  13   17]]
# AUC 0.6582741116751268
# [0.70013536 0.67974619 0.67654822 0.53989848 0.65827411] -- 0.6509204737732656 0.05707848763505407
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
score1 = train_cv(X, y, model1) # LR
score2 = train_cv(X, y, model2) # XGB
score3 = train_cv(X, y, model3) # NB
score = train_cv(X, y, model) # Voting

# %%
tmp = pd.DataFrame({
    'LR': score1,
    'XGB': score2,
    'NB': score3,
    'Ensemble': score,
})
tmp.loc['mean'] = tmp.mean()
tmp.loc['std'] = tmp.std()
tmp
# Out:
#       Ensemble        LR        NB       XGB
# 0     0.700135  0.701354  0.592504  0.557310
# 1     0.679746  0.682995  0.596464  0.527208
# 2     0.676548  0.674196  0.571650  0.641201
# 3     0.539898  0.536904  0.499594  0.573367
# 4     0.658274  0.658156  0.579442  0.565178
# mean  0.650920  0.650721  0.567931  0.572853
# std   0.057078  0.058594  0.035311  0.037565
